# %% [markdown]
# # Plot Maps with Geopanda

# %%
import numpy as np
import pandas as pd
import geopandas
from shapely import wkt
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Registered business locations

# %%
df_business = pd.read_csv("../data/external/Registered_Business_Locations_-_San_Francisco.csv")
print("Shape of the dataset: ", df_business.shape)
df_business.head(5)
# Out:
# C:\Users\Benjamin\Anaconda3\envs\datacamp\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (12,13,14,15,21,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Shape of the dataset:  (250193, 26)
#       Location Id  Business Account Number     Ownership Name  \
# 0  1103593-08-161                  1049564  Anjan Rajbhandari
# 1  1218784-04-191                  1100756      Luisa Alberto
# 2  1223199-05-191                  1102424       Sunrun, Inc.
# 3  1220748-05-191                  1101579    Felix Hernandez
# 4  1135452-02-171                  1065102          Tirta Llc
#
#            DBA Name    Street Address           City State  Source Zipcode  \
# 0              Uber  28134 Harvey Ave        Hayward    CA         94544.0
# 1      High Five Sf       467 14th St  San Francisco    CA         94103.0
# 2       Sunrun, Inc     595 Market St  San Francisco    CA         94105.0
# 3  Tru-Tec Electric      44 Mcaker Ct      San Mateo    CA         94403.0
# 4             Tirta  105 Hudson St 6s  New York City    NY         10013.0
#
#   Business Start Date Business End Date  ... NAICS Code  \
# 0          03/24/2014        12/31/2017  ...        NaN
# 1          04/15/2019        04/15/2019  ...        NaN
# 2          06/01/2008        06/01/2008  ...  2200-2299
# 3          05/06/2019        06/18/2019  ...        NaN
# 4          06/09/2016        12/23/2018  ...        NaN
#
#   NAICS Code Description Parking Tax Transient Occupancy Tax LIC Code  \
# 0                    NaN       False                   False      NaN
# 1                    NaN       False                   False      NaN
# 2              Utilities       False                   False      NaN
# 3                    NaN       False                   False      NaN
# 4                    NaN       False                   False      NaN
#
#   LIC Code Description Supervisor District  \
# 0                  NaN                 NaN
# 1                  NaN                 8.0
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
#
#   Neighborhoods - Analysis Boundaries  Business Corridor  Business Location
# 0                                 NaN                NaN                NaN
# 1                             Mission                NaN                NaN
# 2                                 NaN                NaN                NaN
# 3                                 NaN                NaN                NaN
# 4                                 NaN                NaN                NaN
#
# [5 rows x 26 columns]

# %%
# proportion of NaN values
df_business.isna().sum() / df_business.shape[0]
# Out:
# Location Id                            0.000000
# Business Account Number                0.000000
# Ownership Name                         0.000000
# DBA Name                               0.000000
# Street Address                         0.000016
# City                                   0.000763
# State                                  0.002462
# Source Zipcode                         0.001059
# Business Start Date                    0.000000
# Business End Date                      0.598634
# Location Start Date                    0.000000
# Location End Date                      0.499670
# Mail Address                           0.386098
# Mail City                              0.401486
# Mail Zipcode                           0.401574
# Mail State                             0.401582
# NAICS Code                             0.377569
# NAICS Code Description                 0.377569
# Parking Tax                            0.000000
# Transient Occupancy Tax                0.000000
# LIC Code                               0.933455
# LIC Code Description                   0.941329
# Supervisor District                    0.408433
# Neighborhoods - Analysis Boundaries    0.408453
# Business Corridor                      0.998717
# Business Location                      0.331184
# dtype: float64

# %%
df_business[df_business['City'] == 'San Francisco'].dropna(subset=['Business Location']).head()
# Out:
#         Location Id  Business Account Number              Ownership Name  \
# 212  0082261-02-001                    82261         Lindstrom Bernice G
# 213  0082477-01-001                    82477             Savitsky Eileen
# 214  0094814-02-001                    94814          Villarreal Jesse A
# 215  0105841-01-001                   105841              Cochran Kimo J
# 216  0111436-04-001                   111436  Scholten James H & Helen M
#
#              DBA Name     Street Address           City State  Source Zipcode  \
# 212   2240 Bay St Apt        2240 Bay St  San Francisco    CA         94123.0
# 213   Savitsky Eileen  2550 Greenwich St  San Francisco    CA         94123.0
# 214  T & M Properties       25 Virgil St  San Francisco    CA         94110.0
# 215             Kimos       1351 Polk St  San Francisco    CA         94109.0
# 216  1595 Noe St Apts        1595 Noe St  San Francisco    CA         94131.0
#
#     Business Start Date Business End Date  ... NAICS Code  \
# 212          01/01/1973        04/30/2015  ...        NaN
# 213          10/14/1971        10/20/2007  ...        NaN
# 214          09/10/1975        02/28/2014  ...        NaN
# 215          06/23/1977        01/30/2008  ...        NaN
# 216          05/13/1976        06/30/2018  ...        NaN
#
#     NAICS Code Description Parking Tax Transient Occupancy Tax LIC Code  \
# 212                    NaN       False                   False      NaN
# 213                    NaN       False                   False      NaN
# 214                    NaN       False                   False      NaN
# 215                    NaN       False                   False      NaN
# 216                    NaN       False                   False      NaN
#
#     LIC Code Description Supervisor District  \
# 212                  NaN                 2.0
# 213                  NaN                 2.0
# 214                  NaN                 9.0
# 215                  NaN                 3.0
# 216                  NaN                 8.0
#
#     Neighborhoods - Analysis Boundaries  Business Corridor  \
# 212                              Marina                NaN
# 213                              Marina                NaN
# 214                             Mission                NaN
# 215                            Nob Hill                NaN
# 216                          Noe Valley                NaN
#
#                  Business Location
# 212  POINT (-122.443939 37.801744)
# 213  POINT (-122.441665 37.798214)
# 214  POINT (-122.415494 37.750228)
# 215  POINT (-122.420437 37.789307)
# 216  POINT (-122.431121 37.743653)
#
# [5 rows x 26 columns]

# %%
X_df = df_business[df_business['City'] == 'San Francisco'].dropna(subset=['Business Location'])
X_df.drop(columns=['LIC Code', 'LIC Code Description', 'Business Corridor'], inplace=True)
X_df['Business Location'] = X_df['Business Location'].apply(wkt.loads)
geo_X_df = geopandas.GeoDataFrame(X_df, geometry='Business Location')
print(type(geo_X_df))
geo_X_df.sample(5)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#            Location Id  Business Account Number            Ownership Name  \
# 4950    0187574-02-001                   187574           Meyers Albert C
# 62213   0913383-01-001                   913383               Susan Young
# 49648   0471932-01-001                   471932  Wedgewood Travel Usa Inc
# 119990  0359019-01-001                   359019            124 Turk St Lp
# 46516   0466586-01-001                   466586      Golden Pearl Spa Llc
#
#                         DBA Name    Street Address           City State  \
# 4950          Alber Construction  90 Monterey Blvd  San Francisco    CA
# 62213            Glen Park Nails      74 Wilder St  San Francisco    CA
# 49648   Wedgewood Travel Usa Inc   1630 Union St 3  San Francisco    CA
# 119990            124 Turk St Lp       124 Turk St  San Francisco    CA
# 46516       Golden Pearl Spa Llc     629 Taylor St  San Francisco    CA
#
#         Source Zipcode Business Start Date Business End Date  ...  \
# 4950           94131.0          11/08/2011        03/30/2012  ...
# 62213          94131.0          04/12/1995        12/31/2014  ...
# 49648          94123.0          06/01/2012        02/28/2019  ...
# 119990         94102.0          12/31/2006               NaN  ...
# 46516          94102.0          02/10/2012        06/30/2019  ...
#
#             Mail City Mail Zipcode Mail State NAICS Code  \
# 4950              NaN          NaN        NaN        NaN
# 62213             NaN          NaN        NaN        NaN
# 49648             NaN          NaN        NaN        NaN
# 119990  San Francisco        94131         CA  5300-5399
# 46516             NaN          NaN        NaN        NaN
#
#                              NAICS Code Description Parking Tax  \
# 4950                                            NaN       False
# 62213                                           NaN       False
# 49648                                           NaN       False
# 119990  Real Estate and Rental and Leasing Services       False
# 46516                                           NaN       False
#
#        Transient Occupancy Tax Supervisor District  \
# 4950                     False                 7.0
# 62213                    False                 8.0
# 49648                    False                 2.0
# 119990                   False                 6.0
# 46516                    False                 NaN
#
#         Neighborhoods - Analysis Boundaries            Business Location
# 4950                     West of Twin Peaks  POINT (-122.43713 37.73164)
# 62213                             Glen Park  POINT (-122.43342 37.73417)
# 49648                                Marina  POINT (-122.42613 37.79828)
# 119990                           Tenderloin  POINT (-122.41133 37.78315)
# 46516                                   NaN  POINT (-122.41179 37.78823)
#
# [5 rows x 23 columns]

# %%
geo_X_df.plot(figsize=(13,10), marker="o", #mfc="red",
              markersize=8, #markeredgecolor="black",
              alpha=0.3)
plt.show()

# %%
nbrhoods = geopandas.read_file("../data/external/geo_export_cef81227-9d5f-4ba8-9646-6a4e0ac30e0d.shp")
nbrhoods.head()
# Out:
#                    nhood                                           geometry
# 0  Bayview Hunters Point  POLYGON ((-122.38158 37.75307, -122.38157 37.7...
# 1         Bernal Heights  POLYGON ((-122.40361 37.74934, -122.40378 37.7...
# 2    Castro/Upper Market  POLYGON ((-122.42656 37.76948, -122.42695 37.7...
# 3              Chinatown  POLYGON ((-122.40623 37.79756, -122.40551 37.7...
# 4              Excelsior  POLYGON ((-122.42398 37.73155, -122.42392 37.7...

# %%
nbrhoods.plot(figsize=(12,14))

# %%
fig, ax = plt.subplots(1, figsize=(30,20))
base = nbrhoods.plot(ax=ax)

# plotting business locations
geo_X_df.plot(ax=base, marker="o", #color='darkred',
             column='Supervisor District', cmap='cool',
             )
#_ = ax.axis('off')
ax.set_title("Business locations in SF")
plt.show()

# %%
df_bus = pd.read_csv('../data/external/Active_Business_Locations.csv')
df_bus.head(10)
# Out:
#       Location Id  Business Account Number      Ownership Name  \
# 0  1003537-08-141                  1002310    Rocket Games Inc
# 1  1027106-04-151                  1002310    Rocket Games Inc
# 2  1027107-04-151                  1002310    Rocket Games Inc
# 3  1027108-04-151                  1002310    Rocket Games Inc
# 4  1193440-06-181                  1002310    Rocket Games Inc
# 5  1240100-12-191                  1079507       Regina Jayubo
# 6  1240099-12-191                  1085864        Lumen Sivitz
# 7  1240098-12-191                  1107210  Christina Anguiano
# 8  1240092-12-191                  1109278       Michelle King
# 9  1240097-12-191                  1105221     Tcfi Home 1 Llc
#
#              DBA Name           Street Address           City State  \
# 0    Rocket Games Inc  251 Rhode Island St 211  San Francisco    CA
# 1  Diamond Club Slots           360 3rd St 700  San Francisco    CA
# 2    Easy Money Slots           360 3rd St 700  San Francisco    CA
# 3     Lady Luck Slots           360 3rd St 700  San Francisco    CA
# 4    Rocket Speed Inc           501 2nd St 211  San Francisco    CA
# 5              Regson        655 5th St Unit 8  San Francisco    CA
# 6           Lightwork     275 States St Unit A  San Francisco    CA
# 7  Christina Anguiano      240 West Portal Ave  San Francisco    CA
# 8          Posh Salon         2444 Fillmore St  San Fransisco    CA
# 9     Tcfi Home 1 Llc               156 Noe St  San Francisco    CA
#
#    Source Zipcode Business Start Date  Business End Date Location Start Date  \
# 0         94103.0          06/26/2013                NaN          06/26/2013
# 1         94107.0          06/26/2013                NaN          04/29/2015
# 2         94107.0          06/26/2013                NaN          04/29/2015
# 3         94107.0          06/26/2013                NaN          04/29/2015
# 4         94107.0          06/26/2013                NaN          08/01/2016
# 5         94107.0          05/01/2017                NaN          12/07/2019
# 6         94114.0          04/03/2018                NaN          10/28/2019
# 7         94127.0          10/02/2019                NaN          12/01/2019
# 8         94115.0          12/01/2019                NaN          12/01/2019
# 9         94114.0          06/21/2019                NaN          12/03/2019
#
#    Location End Date          Mail Address  \
# 0                NaN                   NaN
# 1                NaN                   NaN
# 2                NaN                   NaN
# 3                NaN                   NaN
# 4                NaN                   NaN
# 5                NaN      655 5th St Apt 8
# 6                NaN  34 Rausch St Apt 301
# 7                NaN         1638 Deems St
# 8                NaN           725 Glen Dr
# 9                NaN      36 Divisadero St
#
#                                    Business Location
# 0  251 RHODE ISLAND ST\nSAN FRANCISCO, CA 94103\n...
# 1  360 3RD ST\nSAN FRANCISCO, CA 94107\n(37.78307...
# 2  360 3RD ST\nSAN FRANCISCO, CA 94107\n(37.78307...
# 3  360 3RD ST\nSAN FRANCISCO, CA 94107\n(37.78307...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
# proportion of NaN values
df_bus.isna().sum() / df_bus.shape[0]
# Out:
# Location Id                0.000000
# Business Account Number    0.000000
# Ownership Name             0.000000
# DBA Name                   0.000000
# Street Address             0.000008
# City                       0.000496
# State                      0.002567
# Source Zipcode             0.001480
# Business Start Date        0.000000
# Business End Date          1.000000
# Location Start Date        0.000000
# Location End Date          1.000000
# Mail Address               0.000040
# Business Location          0.437369
# dtype: float64

# %%
df_bus.loc[121]
# Out:
# Location Id                                         0016366-01-001
# Business Account Number                                      16366
# Ownership Name                                      Latch Tile Inc
# DBA Name                                            Latch Tile Inc
# Street Address                                     1314 Donner Ave
# City                                                 San Francisco
# State                                                           CA
# Source Zipcode                                               94124
# Business Start Date                                     10/01/1968
# Business End Date                                              NaN
# Location Start Date                                     05/09/2000
# Location End Date                                              NaN
# Mail Address                                       1314 DONNER AVE
# Business Location          1314 DONNER ST\nSan Francisco, CA 94124
# Name: 121, dtype: object

# %%
X_bus = df_bus[df_bus['City'] == 'San Francisco'].dropna(subset=['Business Location'])
X_bus.drop(columns=['Business End Date', 'Location End Date'], inplace=True)
X_bus['latitude'] =  X_bus['Business Location'].apply(lambda x: (x[x.rfind('(')+1:x.rfind(' ')-1]))
X_bus['longitude'] =  X_bus['Business Location'].apply(lambda x: (x[x.rfind(' ')+1:x.rfind(')')-1]))
X_bus['latitude'] = pd.to_numeric(X_bus['latitude'], downcast='float', errors='coerce')
X_bus['longitude'] = pd.to_numeric(X_bus['longitude'], downcast='float', errors='coerce')
X_bus.dropna(subset=['latitude', 'longitude'], inplace=True)
X_bus = X_bus[(X_bus['longitude'] <= -121.) & (X_bus['latitude'] <= 37.84) & (X_bus['latitude'] >= 37.70)]
X_bus.head(10)
# Out:
#         Location Id  Business Account Number                Ownership Name  \
# 0    1003537-08-141                  1002310              Rocket Games Inc
# 1    1027106-04-151                  1002310              Rocket Games Inc
# 2    1027107-04-151                  1002310              Rocket Games Inc
# 3    1027108-04-151                  1002310              Rocket Games Inc
# 13   0371506-03-001                   371506  Bayview Real Estate/mortgage
# 14   0440448-01-001                   440448  Primary Residential Mortgage
# 18   1041647-10-151                  1019443         Whirlpool Corporation
# 331  0000028-02-001                       28               Ferrando Louise
# 332  0000052-01-001                       52              Ideal Novak Corp
# 333  0000071-03-001                       71             Tournahu George L
#
#                          DBA Name           Street Address           City  \
# 0                Rocket Games Inc  251 Rhode Island St 211  San Francisco
# 1              Diamond Club Slots           360 3rd St 700  San Francisco
# 2                Easy Money Slots           360 3rd St 700  San Francisco
# 3                 Lady Luck Slots           360 3rd St 700  San Francisco
# 13    Bayview Real Estate/mortage             388 12th Ave  San Francisco
# 14   Primary Residential Mortgage             1746 18th St  San Francisco
# 18            1751 Carroll Avenue         1751 Carroll Ave  San Francisco
# 331              3101 Laguna Apts           3101 Laguna St  San Francisco
# 332              Ideal Novak Corp            8 Mendosa Ave  San Francisco
# 333          1840-42 Jefferson St    1840 Jefferson St #42  San Francisco
#
#     State  Source Zipcode Business Start Date Location Start Date  \
# 0      CA         94103.0          06/26/2013          06/26/2013
# 1      CA         94107.0          06/26/2013          04/29/2015
# 2      CA         94107.0          06/26/2013          04/29/2015
# 3      CA         94107.0          06/26/2013          04/29/2015
# 13     CA         94118.0          03/01/2014          03/01/2014
# 14     CA         94107.0          07/17/2008          07/17/2008
# 18     CA         94124.0          08/26/2015          08/26/2015
# 331    CA         94123.0          09/30/1993          09/30/1993
# 332    CA         94116.0          10/01/1968          10/01/1968
# 333    CA         94123.0          10/01/1968          10/07/1991
#
#                 Mail Address  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 13             388-12th Ave.
# 14             1480 N 2200 W
# 18               2000 N M 63
# 331       2799 CALIFORNIA ST
# 332            8 MENDOSA AVE
# 333  4444 GEARY BLVD STE 100
#
#                                      Business Location   latitude   longitude
# 0    251 RHODE ISLAND ST\nSAN FRANCISCO, CA 94103\n...  37.766731 -122.402802
# 1    360 3RD ST\nSAN FRANCISCO, CA 94107\n(37.78307...  37.783077 -122.398041
# 2    360 3RD ST\nSAN FRANCISCO, CA 94107\n(37.78307...  37.783077 -122.398041
# 3    360 3RD ST\nSAN FRANCISCO, CA 94107\n(37.78307...  37.783077 -122.398041
# 13   388 12TH AVE\nSan Francisco, CA 94118\n(37.781...  37.781033 -122.470734
# 14   1746 18TH ST\nSAN FRANCISCO, CA 94107\n(37.762...  37.762390 -122.399773
# 18   1751 CARROLL AVE\nSAN FRANCISCO, CA 94124\n(37...  37.725414 -122.394150
# 331  3101 LAGUNA ST\nSan Francisco, CA 94123\n(37.7...  37.799824 -122.430992
# 332  8 MENDOSA AVE\nSan Francisco, CA 94116\n(37.74...  37.748924 -122.465073
# 333  1840 42 JEFFERSON ST\nSan Francisco, CA 94109\...  37.804760 -122.442787

# %%
gdf_bus = geopandas.GeoDataFrame(
    X_bus, geometry=geopandas.points_from_xy(X_bus.longitude, X_bus.latitude))
gdf_bus.head()
# Out:
#        Location Id  Business Account Number                Ownership Name  \
# 0   1003537-08-141                  1002310              Rocket Games Inc
# 1   1027106-04-151                  1002310              Rocket Games Inc
# 2   1027107-04-151                  1002310              Rocket Games Inc
# 3   1027108-04-151                  1002310              Rocket Games Inc
# 13  0371506-03-001                   371506  Bayview Real Estate/mortgage
#
#                        DBA Name           Street Address           City State  \
# 0              Rocket Games Inc  251 Rhode Island St 211  San Francisco    CA
# 1            Diamond Club Slots           360 3rd St 700  San Francisco    CA
# 2              Easy Money Slots           360 3rd St 700  San Francisco    CA
# 3               Lady Luck Slots           360 3rd St 700  San Francisco    CA
# 13  Bayview Real Estate/mortage             388 12th Ave  San Francisco    CA
#
#     Source Zipcode Business Start Date Location Start Date   Mail Address  \
# 0          94103.0          06/26/2013          06/26/2013            NaN
# 1          94107.0          06/26/2013          04/29/2015            NaN
# 2          94107.0          06/26/2013          04/29/2015            NaN
# 3          94107.0          06/26/2013          04/29/2015            NaN
# 13         94118.0          03/01/2014          03/01/2014  388-12th Ave.
#
#                                     Business Location   latitude   longitude  \
# 0   251 RHODE ISLAND ST\nSAN FRANCISCO, CA 94103\n...  37.766731 -122.402802
# 1   360 3RD ST\nSAN FRANCISCO, CA 94107\n(37.78307...  37.783077 -122.398041
# 2   360 3RD ST\nSAN FRANCISCO, CA 94107\n(37.78307...  37.783077 -122.398041
# 3   360 3RD ST\nSAN FRANCISCO, CA 94107\n(37.78307...  37.783077 -122.398041
# 13  388 12TH AVE\nSan Francisco, CA 94118\n(37.781...  37.781033 -122.470734
#
#                        geometry
# 0   POINT (-122.40280 37.76673)
# 1   POINT (-122.39804 37.78308)
# 2   POINT (-122.39804 37.78308)
# 3   POINT (-122.39804 37.78308)
# 13  POINT (-122.47073 37.78103)

# %%
fig, ax = plt.subplots(1, figsize=(30,20))
base = nbrhoods.plot(ax=ax)
# plotting business locations
gdf_bus.plot(ax=base, marker="o", color='darkred',
             #column='Source Zipcode', cmap='cool',
             )
#_ = ax.axis('off')
#plt.legend()
ax.set_title("Business locations in SF")
plt.show()

# %% [markdown]
# ## Schools

# %%
df_sch = pd.read_csv('../data/external/Map_of_schools.csv')
df_sch.head()
# Out:
#                                          Campus Name CCSF Entity  Lower Grade  \
# 0                 Milk, Harvey Milk Childrens Center       SFUSD           -2
# 1                         Mckinley Elementary School       SFUSD            0
# 2  Jewish Community Center San Francisco - Rosenb...     Private           -2
# 3                             Eureka Learning Center     Private           -2
# 4                     Noriega Early Education School       SFUSD           -2
#
#    Upper Grade Grade Range               Category Map Label  Lower Age  \
# 0           -1          PK               USD PreK    CDC095          3
# 1            5         K-5         USD Grades K-5     PS075          5
# 2           -1          PK  Independent / Private    CDC058          3
# 3           -1          PK  Independent / Private    CDC035          3
# 4            5        PK-5          USD PreK/TK-5     PS085          3
#
#    Upper Age General Type      CDS Code  \
# 0          4          CDC           NaN
# 1         10           PS  3.868479e+13
# 2          4          CDC  3.805047e+08
# 3          4          CDC  3.868479e+13
# 4         10           PS  3.868478e+13
#
#                                Campus Address  Supervisor District  \
# 0        841 ELLIS ST, SAN FRANCISCO CA 94117                    6
# 1       1025 14TH ST, San Francisco, CA 94114                    8
# 2  325 ARGUELLO BLVD, SAN FRANCISCO, CA 94118                    1
# 3     464 DIAMOND ST, SAN FRANCISCO, CA 94114                    8
# 4      1775 44TH AVE, San Francisco, CA 94122                    4
#
#    County FIPS    County Name                    Location 1
# 0         6075  SAN FRANCISCO  CA\n(37.783802, -122.420105)
# 1         6075  SAN FRANCISCO  CA\n(37.766884, -122.436279)
# 2         6075  SAN FRANCISCO  CA\n(37.784588, -122.459488)
# 3         6075  SAN FRANCISCO  CA\n(37.754967, -122.437004)
# 4         6075  SAN FRANCISCO  CA\n(37.753834, -122.503654)

# %%
# proportion of NaN values
df_business.isna().sum() / df_business.shape[0]
# Out:
# Location Id                            0.000000
# Business Account Number                0.000000
# Ownership Name                         0.000000
# DBA Name                               0.000000
# Street Address                         0.000016
# City                                   0.000763
# State                                  0.002462
# Source Zipcode                         0.001059
# Business Start Date                    0.000000
# Business End Date                      0.598634
# Location Start Date                    0.000000
# Location End Date                      0.499670
# Mail Address                           0.386098
# Mail City                              0.401486
# Mail Zipcode                           0.401574
# Mail State                             0.401582
# NAICS Code                             0.377569
# NAICS Code Description                 0.377569
# Parking Tax                            0.000000
# Transient Occupancy Tax                0.000000
# LIC Code                               0.933455
# LIC Code Description                   0.941329
# Supervisor District                    0.408433
# Neighborhoods - Analysis Boundaries    0.408453
# Business Corridor                      0.998717
# Business Location                      0.331184
# dtype: float64
