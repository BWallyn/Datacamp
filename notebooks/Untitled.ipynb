# %%
## load data
# %matplotlib inline
import imp
import pandas as pd
import numpy as np
import geopandas
from matplotlib import pyplot as plt
import seaborn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-068329ccbda2> in <module>
#       4 import pandas as pd
#       5 import numpy as np
# ----> 6 import geopandas
#       7 from matplotlib import pyplot as plt
#       8 import seaborn
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
X_df = pd.read_csv('../data/interim/enhanced_restaurant_scores.csv')

# %%
X_df.head()
# Out:
#    Unnamed: 0  business_id            business_name  business_address  \
# 0           0        69618  Fancy Wheatfield Bakery  1362 Stockton St
# 1           1        97975               BREADBELLY   1408 Clement St
# 2           2        69487   Hakkasan San Francisco       1 Kearny St
# 3           3        91044    Chopsticks Restaurant   4615 Mission St
# 4           4        85987                  Tselogs      552 Jones St
#
#    business_city business_state business_postal_code  business_latitude  \
# 0  San Francisco             CA                94133          37.798473
# 1  San Francisco             CA                94118          37.782709
# 2  San Francisco             CA                94108          37.787769
# 3  San Francisco             CA                94112          37.724334
# 4  San Francisco             CA                94102          37.786457
#
#    business_longitude business_location  business_phone_number  \
# 0         -122.408648               NaN                    NaN
# 1         -122.474410               NaN           1.415724e+10
# 2         -122.404024               NaN                    NaN
# 3         -122.434942               NaN                    NaN
# 4         -122.413001               NaN                    NaN
#
#     inspection_id         inspection_date  inspection_score  \
# 0  69618_20190304  03/04/2019 12:00:00 AM               NaN
# 1  97975_20190725  07/25/2019 12:00:00 AM              96.0
# 2  69487_20180418  04/18/2018 12:00:00 AM              88.0
# 3  91044_20170818  08/18/2017 12:00:00 AM               NaN
# 4  85987_20180412  04/12/2018 12:00:00 AM              94.0
#
#              inspection_type           violation_id  \
# 0                  Complaint  69618_20190304_103130
# 1      Routine - Unscheduled  97975_20190725_103124
# 2      Routine - Unscheduled  69487_20180418_103119
# 3  Non-inspection site visit                    NaN
# 4      Routine - Unscheduled  85987_20180412_103132
#
#                                violation_description  risk_category  \
# 0           Inadequate sewage or wastewater disposal  Moderate Risk
# 1  Inadequately cleaned or sanitized food contact...  Moderate Risk
# 2  Inadequate and inaccessible handwashing facili...  Moderate Risk
# 3                                                NaN            NaN
# 4                           Improper thawing methods  Moderate Risk
#
#                                full_adress
# 0  1362 Stockton St San Francisco 94133 CA
# 1   1408 Clement St San Francisco 94118 CA
# 2       1 Kearny St San Francisco 94108 CA
# 3   4615 Mission St San Francisco 94112 CA
# 4      552 Jones St San Francisco 94102 CA

# %%
nbrhoods = geopandas.read_file("../data/external/geo_export_cef81227-9d5f-4ba8-9646-6a4e0ac30e0d.shp")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1b02f3cf662d> in <module>
# ----> 1 nbrhoods = geopandas.read_file("../data/external/geo_export_cef81227-9d5f-4ba8-9646-6a4e0ac30e0d.shp")
#
# NameError: name 'geopandas' is not defined
